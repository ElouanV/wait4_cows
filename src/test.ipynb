# %%
from utils_paths import load_parquet_or_csv, get_accelero_id_from_parquet_or_csv_files
from utils_plotting import *
import pandas as pd
import pickle
import networkx as nx

# %%
with open("../outputs/temporal_graphs/temporal_graphs_rssineg75_snap20s_mean_20251119_115334.pkl",'rb') as f:
    temporal_graphs = pickle.load(f)

temporal_graphs
# Out:
# [{'timestamp': Timestamp('2025-03-17 00:00:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93fad07610>,
#   'num_nodes': 49,
#   'num_edges': 156,
#   'num_measurements': 161},
#  {'timestamp': Timestamp('2025-03-17 00:00:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ed38bf90>,
#   'num_nodes': 49,
#   'num_edges': 752,
#   'num_measurements': 943},
#  {'timestamp': Timestamp('2025-03-17 00:01:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93e8384090>,
#   'num_nodes': 49,
#   'num_edges': 1155,
#   'num_measurements': 2202},
#  {'timestamp': Timestamp('2025-03-17 00:01:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93e36858d0>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2218},
#  {'timestamp': Timestamp('2025-03-17 00:01:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93f0728350>,
#   'num_nodes': 49,
#   'num_edges': 1156,
#   'num_measurements': 2217},
#  {'timestamp': Timestamp('2025-03-17 00:02:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93e0dcdb50>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2231},
#  {'timestamp': Timestamp('2025-03-17 00:02:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93e044c190>,
#   'num_nodes': 49,
#   'num_edges': 1155,
#   'num_measurements': 2230},
#  {'timestamp': Timestamp('2025-03-17 00:02:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93df95db50>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2227},
#  {'timestamp': Timestamp('2025-03-17 00:03:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93dee435d0>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2241},
#  {'timestamp': Timestamp('2025-03-17 00:03:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93de3a30d0>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2238},
#  {'timestamp': Timestamp('2025-03-17 00:03:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93dd87b6d0>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2213},
#  {'timestamp': Timestamp('2025-03-17 00:04:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93dcbcfed0>,
#   'num_nodes': 49,
#   'num_edges': 1157,
#   'num_measurements': 2210},
#  {'timestamp': Timestamp('2025-03-17 00:04:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93dc1b1790>,
#   'num_nodes': 49,
#   'num_edges': 1154,
#   'num_measurements': 2218},
#  {'timestamp': Timestamp('2025-03-17 00:04:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93db4d1010>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2193},
#  {'timestamp': Timestamp('2025-03-17 00:05:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93dab7dbd0>,
#   'num_nodes': 49,
#   'num_edges': 1156,
#   'num_measurements': 2251},
#  {'timestamp': Timestamp('2025-03-17 00:05:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93da021650>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2250},
#  {'timestamp': Timestamp('2025-03-17 00:05:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93d96034d0>,
#   'num_nodes': 49,
#   'num_edges': 1154,
#   'num_measurements': 2197},
#  {'timestamp': Timestamp('2025-03-17 00:06:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93d8c4d310>,
#   'num_nodes': 49,
#   'num_edges': 1149,
#   'num_measurements': 2242},
#  {'timestamp': Timestamp('2025-03-17 00:06:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93d82618d0>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2234},
#  {'timestamp': Timestamp('2025-03-17 00:06:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93d770e150>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2210},
#  {'timestamp': Timestamp('2025-03-17 00:07:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93d6c59710>,
#   'num_nodes': 49,
#   'num_edges': 1155,
#   'num_measurements': 2239},
#  {'timestamp': Timestamp('2025-03-17 00:07:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93d62a2650>,
#   'num_nodes': 49,
#   'num_edges': 1154,
#   'num_measurements': 2209},
#  {'timestamp': Timestamp('2025-03-17 00:07:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93d564c2d0>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2204},
#  {'timestamp': Timestamp('2025-03-17 00:08:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93d4b38590>,
#   'num_nodes': 49,
#   'num_edges': 1155,
#   'num_measurements': 2224},
#  {'timestamp': Timestamp('2025-03-17 00:08:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93d419d610>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2232},
#  {'timestamp': Timestamp('2025-03-17 00:08:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93d35f5410>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2199},
#  {'timestamp': Timestamp('2025-03-17 00:09:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93d2cb2290>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2251},
#  {'timestamp': Timestamp('2025-03-17 00:09:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93d20f2150>,
#   'num_nodes': 49,
#   'num_edges': 1156,
#   'num_measurements': 2218},
#  {'timestamp': Timestamp('2025-03-17 00:09:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93d17757d0>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2279},
#  {'timestamp': Timestamp('2025-03-17 00:10:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93d0db7010>,
#   'num_nodes': 49,
#   'num_edges': 1156,
#   'num_measurements': 2191},
#  {'timestamp': Timestamp('2025-03-17 00:10:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93d01d1c10>,
#   'num_nodes': 49,
#   'num_edges': 1152,
#   'num_measurements': 2243},
#  {'timestamp': Timestamp('2025-03-17 00:10:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cf6e9150>,
#   'num_nodes': 49,
#   'num_edges': 1154,
#   'num_measurements': 2191},
#  {'timestamp': Timestamp('2025-03-17 00:11:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ced0bf90>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2273},
#  {'timestamp': Timestamp('2025-03-17 00:11:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93e2fed650>,
#   'num_nodes': 49,
#   'num_edges': 1156,
#   'num_measurements': 2214},
#  {'timestamp': Timestamp('2025-03-17 00:11:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93e24e0e50>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2181},
#  {'timestamp': Timestamp('2025-03-17 00:12:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93e1b35b90>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2304},
#  {'timestamp': Timestamp('2025-03-17 00:12:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca21b7d0>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2140},
#  {'timestamp': Timestamp('2025-03-17 00:12:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93c9754890>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2238},
#  {'timestamp': Timestamp('2025-03-17 00:13:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93c8c5d350>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2284},
#  {'timestamp': Timestamp('2025-03-17 00:13:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93c80db090>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2233},
#  {'timestamp': Timestamp('2025-03-17 00:13:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93c76dcad0>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2213},
#  {'timestamp': Timestamp('2025-03-17 00:14:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93c6db6550>,
#   'num_nodes': 49,
#   'num_edges': 1157,
#   'num_measurements': 2212},
#  {'timestamp': Timestamp('2025-03-17 00:14:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93c62a59d0>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2262},
#  {'timestamp': Timestamp('2025-03-17 00:14:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93c5641bd0>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2217},
#  {'timestamp': Timestamp('2025-03-17 00:15:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93c4b06050>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2205},
#  {'timestamp': Timestamp('2025-03-17 00:15:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93c3fed710>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2241},
#  {'timestamp': Timestamp('2025-03-17 00:15:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93c3601c10>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2208},
#  {'timestamp': Timestamp('2025-03-17 00:16:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93c2bdbad0>,
#   'num_nodes': 49,
#   'num_edges': 1163,
#   'num_measurements': 2259},
#  {'timestamp': Timestamp('2025-03-17 00:16:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93c22914d0>,
#   'num_nodes': 49,
#   'num_edges': 1157,
#   'num_measurements': 2176},
#  {'timestamp': Timestamp('2025-03-17 00:16:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93c16bcd50>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2250},
#  {'timestamp': Timestamp('2025-03-17 00:17:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93c0d1b490>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2250},
#  {'timestamp': Timestamp('2025-03-17 00:17:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93c03a1d50>,
#   'num_nodes': 49,
#   'num_edges': 1163,
#   'num_measurements': 2216},
#  {'timestamp': Timestamp('2025-03-17 00:17:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93bf6bfad0>,
#   'num_nodes': 49,
#   'num_edges': 1166,
#   'num_measurements': 2264},
#  {'timestamp': Timestamp('2025-03-17 00:18:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93bed4cc90>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2216},
#  {'timestamp': Timestamp('2025-03-17 00:18:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93be24dd90>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2224},
#  {'timestamp': Timestamp('2025-03-17 00:18:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93bd5c5250>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2244},
#  {'timestamp': Timestamp('2025-03-17 00:19:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93bcc8b950>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2232},
#  {'timestamp': Timestamp('2025-03-17 00:19:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93bc172690>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2242},
#  {'timestamp': Timestamp('2025-03-17 00:19:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93bb68e490>,
#   'num_nodes': 49,
#   'num_edges': 1165,
#   'num_measurements': 2257},
#  {'timestamp': Timestamp('2025-03-17 00:20:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93bab99e10>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2187},
#  {'timestamp': Timestamp('2025-03-17 00:20:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b9fc29d0>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2245},
#  {'timestamp': Timestamp('2025-03-17 00:20:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b95cc6d0>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2203},
#  {'timestamp': Timestamp('2025-03-17 00:21:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b8ace590>,
#   'num_nodes': 49,
#   'num_edges': 1163,
#   'num_measurements': 2290},
#  {'timestamp': Timestamp('2025-03-17 00:21:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b81ac850>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2212},
#  {'timestamp': Timestamp('2025-03-17 00:21:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b77b77d0>,
#   'num_nodes': 49,
#   'num_edges': 1163,
#   'num_measurements': 2232},
#  {'timestamp': Timestamp('2025-03-17 00:22:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b6bced90>,
#   'num_nodes': 49,
#   'num_edges': 1149,
#   'num_measurements': 2228},
#  {'timestamp': Timestamp('2025-03-17 00:22:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b625ee10>,
#   'num_nodes': 49,
#   'num_edges': 1167,
#   'num_measurements': 2242},
#  {'timestamp': Timestamp('2025-03-17 00:22:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b56f1910>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2234},
#  {'timestamp': Timestamp('2025-03-17 00:23:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b4bc6b10>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2189},
#  {'timestamp': Timestamp('2025-03-17 00:23:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b40bc250>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2283},
#  {'timestamp': Timestamp('2025-03-17 00:23:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cbe63ed0>,
#   'num_nodes': 49,
#   'num_edges': 1166,
#   'num_measurements': 2207},
#  {'timestamp': Timestamp('2025-03-17 00:24:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cbea3fd0>,
#   'num_nodes': 49,
#   'num_edges': 1163,
#   'num_measurements': 2238},
#  {'timestamp': Timestamp('2025-03-17 00:24:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cbcf0110>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2223},
#  {'timestamp': Timestamp('2025-03-17 00:24:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cbd300d0>,
#   'num_nodes': 49,
#   'num_edges': 1163,
#   'num_measurements': 2219},
#  {'timestamp': Timestamp('2025-03-17 00:25:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cbd781d0>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2228},
#  {'timestamp': Timestamp('2025-03-17 00:25:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cbbb82d0>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2254},
#  {'timestamp': Timestamp('2025-03-17 00:25:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cbbf8150>,
#   'num_nodes': 49,
#   'num_edges': 1163,
#   'num_measurements': 2263},
#  {'timestamp': Timestamp('2025-03-17 00:26:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cbc382d0>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2188},
#  {'timestamp': Timestamp('2025-03-17 00:26:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cbc7c310>,
#   'num_nodes': 49,
#   'num_edges': 1149,
#   'num_measurements': 2215},
#  {'timestamp': Timestamp('2025-03-17 00:26:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cbabc110>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2288},
#  {'timestamp': Timestamp('2025-03-17 00:27:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cbafc1d0>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2193},
#  {'timestamp': Timestamp('2025-03-17 00:27:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cbb44150>,
#   'num_nodes': 49,
#   'num_edges': 1164,
#   'num_measurements': 2246},
#  {'timestamp': Timestamp('2025-03-17 00:27:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cbb84210>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2250},
#  {'timestamp': Timestamp('2025-03-17 00:28:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb9c4250>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2169},
#  {'timestamp': Timestamp('2025-03-17 00:28:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cba04250>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2268},
#  {'timestamp': Timestamp('2025-03-17 00:28:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cba3ff90>,
#   'num_nodes': 49,
#   'num_edges': 1156,
#   'num_measurements': 2213},
#  {'timestamp': Timestamp('2025-03-17 00:29:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cba83e10>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2256},
#  {'timestamp': Timestamp('2025-03-17 00:29:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb8c3e90>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2178},
#  {'timestamp': Timestamp('2025-03-17 00:29:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb903d50>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2282},
#  {'timestamp': Timestamp('2025-03-17 00:30:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb943cd0>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2177},
#  {'timestamp': Timestamp('2025-03-17 00:30:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb987a90>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2273},
#  {'timestamp': Timestamp('2025-03-17 00:30:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb7cba10>,
#   'num_nodes': 49,
#   'num_edges': 1145,
#   'num_measurements': 2166},
#  {'timestamp': Timestamp('2025-03-17 00:31:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb80b590>,
#   'num_nodes': 49,
#   'num_edges': 1145,
#   'num_measurements': 2216},
#  {'timestamp': Timestamp('2025-03-17 00:31:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb84f150>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2293},
#  {'timestamp': Timestamp('2025-03-17 00:31:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb88f1d0>,
#   'num_nodes': 49,
#   'num_edges': 1157,
#   'num_measurements': 2230},
#  {'timestamp': Timestamp('2025-03-17 00:32:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb6cf150>,
#   'num_nodes': 49,
#   'num_edges': 1155,
#   'num_measurements': 2193},
#  {'timestamp': Timestamp('2025-03-17 00:32:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb70efd0>,
#   'num_nodes': 49,
#   'num_edges': 1147,
#   'num_measurements': 2167},
#  {'timestamp': Timestamp('2025-03-17 00:32:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb756cd0>,
#   'num_nodes': 49,
#   'num_edges': 1155,
#   'num_measurements': 2226},
#  {'timestamp': Timestamp('2025-03-17 00:33:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb796bd0>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2251},
#  {'timestamp': Timestamp('2025-03-17 00:33:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb5d69d0>,
#   'num_nodes': 49,
#   'num_edges': 1145,
#   'num_measurements': 2265},
#  {'timestamp': Timestamp('2025-03-17 00:33:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb616650>,
#   'num_nodes': 49,
#   'num_edges': 1155,
#   'num_measurements': 2219},
#  {'timestamp': Timestamp('2025-03-17 00:34:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb65a590>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2190},
#  {'timestamp': Timestamp('2025-03-17 00:34:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb69a310>,
#   'num_nodes': 49,
#   'num_edges': 1154,
#   'num_measurements': 2187},
#  {'timestamp': Timestamp('2025-03-17 00:34:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb4de1d0>,
#   'num_nodes': 49,
#   'num_edges': 1149,
#   'num_measurements': 2253},
#  {'timestamp': Timestamp('2025-03-17 00:35:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb521e90>,
#   'num_nodes': 49,
#   'num_edges': 1146,
#   'num_measurements': 2247},
#  {'timestamp': Timestamp('2025-03-17 00:35:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb561a50>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2276},
#  {'timestamp': Timestamp('2025-03-17 00:35:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb5a1990>,
#   'num_nodes': 49,
#   'num_edges': 1147,
#   'num_measurements': 2197},
#  {'timestamp': Timestamp('2025-03-17 00:36:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cc0e5610>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2278},
#  {'timestamp': Timestamp('2025-03-17 00:36:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cc129550>,
#   'num_nodes': 49,
#   'num_edges': 1155,
#   'num_measurements': 2171},
#  {'timestamp': Timestamp('2025-03-17 00:36:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cc16d390>,
#   'num_nodes': 49,
#   'num_edges': 1151,
#   'num_measurements': 2203},
#  {'timestamp': Timestamp('2025-03-17 00:37:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cc1ad110>,
#   'num_nodes': 49,
#   'num_edges': 1154,
#   'num_measurements': 2260},
#  {'timestamp': Timestamp('2025-03-17 00:37:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb1f0f10>,
#   'num_nodes': 49,
#   'num_edges': 1151,
#   'num_measurements': 2182},
#  {'timestamp': Timestamp('2025-03-17 00:37:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb230c10>,
#   'num_nodes': 49,
#   'num_edges': 1155,
#   'num_measurements': 2232},
#  {'timestamp': Timestamp('2025-03-17 00:38:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb270a90>,
#   'num_nodes': 49,
#   'num_edges': 1148,
#   'num_measurements': 2243},
#  {'timestamp': Timestamp('2025-03-17 00:38:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb0b46d0>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2268},
#  {'timestamp': Timestamp('2025-03-17 00:38:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb0fc690>,
#   'num_nodes': 49,
#   'num_edges': 1145,
#   'num_measurements': 2176},
#  {'timestamp': Timestamp('2025-03-17 00:39:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb13c210>,
#   'num_nodes': 49,
#   'num_edges': 1147,
#   'num_measurements': 2189},
#  {'timestamp': Timestamp('2025-03-17 00:39:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb173f10>,
#   'num_nodes': 49,
#   'num_edges': 1156,
#   'num_measurements': 2285},
#  {'timestamp': Timestamp('2025-03-17 00:39:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cafb7d50>,
#   'num_nodes': 49,
#   'num_edges': 1157,
#   'num_measurements': 2171},
#  {'timestamp': Timestamp('2025-03-17 00:40:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93caff7b90>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2268},
#  {'timestamp': Timestamp('2025-03-17 00:40:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb03fa90>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2154},
#  {'timestamp': Timestamp('2025-03-17 00:40:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb07f7d0>,
#   'num_nodes': 49,
#   'num_edges': 1157,
#   'num_measurements': 2255},
#  {'timestamp': Timestamp('2025-03-17 00:41:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93caec3710>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2253},
#  {'timestamp': Timestamp('2025-03-17 00:41:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93caf03510>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2194},
#  {'timestamp': Timestamp('2025-03-17 00:41:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93caf47250>,
#   'num_nodes': 49,
#   'num_edges': 1156,
#   'num_measurements': 2254},
#  {'timestamp': Timestamp('2025-03-17 00:42:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93caf8b0d0>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2172},
#  {'timestamp': Timestamp('2025-03-17 00:42:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cadcee90>,
#   'num_nodes': 49,
#   'num_edges': 1154,
#   'num_measurements': 2232},
#  {'timestamp': Timestamp('2025-03-17 00:42:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cae12c90>,
#   'num_nodes': 49,
#   'num_edges': 1155,
#   'num_measurements': 2279},
#  {'timestamp': Timestamp('2025-03-17 00:43:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cae52a50>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2161},
#  {'timestamp': Timestamp('2025-03-17 00:43:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cae92a90>,
#   'num_nodes': 49,
#   'num_edges': 1149,
#   'num_measurements': 2245},
#  {'timestamp': Timestamp('2025-03-17 00:43:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cacd66d0>,
#   'num_nodes': 49,
#   'num_edges': 1150,
#   'num_measurements': 2258},
#  {'timestamp': Timestamp('2025-03-17 00:44:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cad1e390>,
#   'num_nodes': 49,
#   'num_edges': 1157,
#   'num_measurements': 2263},
#  {'timestamp': Timestamp('2025-03-17 00:44:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cad5e250>,
#   'num_nodes': 49,
#   'num_edges': 1152,
#   'num_measurements': 2176},
#  {'timestamp': Timestamp('2025-03-17 00:44:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cad9df90>,
#   'num_nodes': 49,
#   'num_edges': 1154,
#   'num_measurements': 2229},
#  {'timestamp': Timestamp('2025-03-17 00:45:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cabe5e10>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2249},
#  {'timestamp': Timestamp('2025-03-17 00:45:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cac25cd0>,
#   'num_nodes': 49,
#   'num_edges': 1152,
#   'num_measurements': 2159},
#  {'timestamp': Timestamp('2025-03-17 00:45:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cac659d0>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2295},
#  {'timestamp': Timestamp('2025-03-17 00:46:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93caca98d0>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2189},
#  {'timestamp': Timestamp('2025-03-17 00:46:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93caaf1650>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2243},
#  {'timestamp': Timestamp('2025-03-17 00:46:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cab315d0>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2236},
#  {'timestamp': Timestamp('2025-03-17 00:47:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cab71550>,
#   'num_nodes': 49,
#   'num_edges': 1149,
#   'num_measurements': 2202},
#  {'timestamp': Timestamp('2025-03-17 00:47:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca9b91d0>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2270},
#  {'timestamp': Timestamp('2025-03-17 00:47:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca9fd150>,
#   'num_nodes': 49,
#   'num_edges': 1152,
#   'num_measurements': 2177},
#  {'timestamp': Timestamp('2025-03-17 00:48:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93caa3ced0>,
#   'num_nodes': 49,
#   'num_edges': 1154,
#   'num_measurements': 2251},
#  {'timestamp': Timestamp('2025-03-17 00:48:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93caa7cc90>,
#   'num_nodes': 49,
#   'num_edges': 1155,
#   'num_measurements': 2219},
#  {'timestamp': Timestamp('2025-03-17 00:48:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca8c4ad0>,
#   'num_nodes': 49,
#   'num_edges': 1155,
#   'num_measurements': 2217},
#  {'timestamp': Timestamp('2025-03-17 00:49:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca904890>,
#   'num_nodes': 49,
#   'num_edges': 1151,
#   'num_measurements': 2251},
#  {'timestamp': Timestamp('2025-03-17 00:49:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca944550>,
#   'num_nodes': 49,
#   'num_edges': 1155,
#   'num_measurements': 2182},
#  {'timestamp': Timestamp('2025-03-17 00:49:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca988350>,
#   'num_nodes': 49,
#   'num_edges': 1155,
#   'num_measurements': 2303},
#  {'timestamp': Timestamp('2025-03-17 00:50:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca7d0190>,
#   'num_nodes': 49,
#   'num_edges': 1147,
#   'num_measurements': 2142},
#  {'timestamp': Timestamp('2025-03-17 00:50:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca807d50>,
#   'num_nodes': 49,
#   'num_edges': 1157,
#   'num_measurements': 2248},
#  {'timestamp': Timestamp('2025-03-17 00:50:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca847bd0>,
#   'num_nodes': 49,
#   'num_edges': 1152,
#   'num_measurements': 2268},
#  {'timestamp': Timestamp('2025-03-17 00:51:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca88b950>,
#   'num_nodes': 49,
#   'num_edges': 1152,
#   'num_measurements': 2225},
#  {'timestamp': Timestamp('2025-03-17 00:51:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca6cf710>,
#   'num_nodes': 49,
#   'num_edges': 1157,
#   'num_measurements': 2231},
#  {'timestamp': Timestamp('2025-03-17 00:51:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca713590>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2252},
#  {'timestamp': Timestamp('2025-03-17 00:52:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca7534d0>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2260},
#  {'timestamp': Timestamp('2025-03-17 00:52:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca793250>,
#   'num_nodes': 49,
#   'num_edges': 1156,
#   'num_measurements': 2159},
#  {'timestamp': Timestamp('2025-03-17 00:52:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca5db0d0>,
#   'num_nodes': 49,
#   'num_edges': 1152,
#   'num_measurements': 2211},
#  {'timestamp': Timestamp('2025-03-17 00:53:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca61ee10>,
#   'num_nodes': 49,
#   'num_edges': 1149,
#   'num_measurements': 2284},
#  {'timestamp': Timestamp('2025-03-17 00:53:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca65eb10>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2180},
#  {'timestamp': Timestamp('2025-03-17 00:53:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca69e850>,
#   'num_nodes': 49,
#   'num_edges': 1157,
#   'num_measurements': 2299},
#  {'timestamp': Timestamp('2025-03-17 00:54:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca4e6710>,
#   'num_nodes': 49,
#   'num_edges': 1144,
#   'num_measurements': 2205},
#  {'timestamp': Timestamp('2025-03-17 00:54:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca526210>,
#   'num_nodes': 49,
#   'num_edges': 1157,
#   'num_measurements': 2264},
#  {'timestamp': Timestamp('2025-03-17 00:54:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca56a090>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2160},
#  {'timestamp': Timestamp('2025-03-17 00:55:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93ca5addd0>,
#   'num_nodes': 49,
#   'num_edges': 1150,
#   'num_measurements': 2284},
#  {'timestamp': Timestamp('2025-03-17 00:55:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b3af5a50>,
#   'num_nodes': 49,
#   'num_edges': 1152,
#   'num_measurements': 2209},
#  {'timestamp': Timestamp('2025-03-17 00:55:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b3b35750>,
#   'num_nodes': 49,
#   'num_edges': 1155,
#   'num_measurements': 2216},
#  {'timestamp': Timestamp('2025-03-17 00:56:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b3b75550>,
#   'num_nodes': 49,
#   'num_edges': 1142,
#   'num_measurements': 2240},
#  {'timestamp': Timestamp('2025-03-17 00:56:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b39b8fd0>,
#   'num_nodes': 49,
#   'num_edges': 1148,
#   'num_measurements': 2249},
#  {'timestamp': Timestamp('2025-03-17 00:56:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b39fcbd0>,
#   'num_nodes': 49,
#   'num_edges': 1150,
#   'num_measurements': 2167},
#  {'timestamp': Timestamp('2025-03-17 00:57:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b3a3c990>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2263},
#  {'timestamp': Timestamp('2025-03-17 00:57:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b3a80810>,
#   'num_nodes': 49,
#   'num_edges': 1154,
#   'num_measurements': 2225},
#  {'timestamp': Timestamp('2025-03-17 00:57:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b38c05d0>,
#   'num_nodes': 49,
#   'num_edges': 1155,
#   'num_measurements': 2264},
#  {'timestamp': Timestamp('2025-03-17 00:58:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b39003d0>,
#   'num_nodes': 49,
#   'num_edges': 1145,
#   'num_measurements': 2180},
#  {'timestamp': Timestamp('2025-03-17 00:58:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b393bed0>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2234},
#  {'timestamp': Timestamp('2025-03-17 00:58:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b397bd90>,
#   'num_nodes': 49,
#   'num_edges': 1144,
#   'num_measurements': 2285},
#  {'timestamp': Timestamp('2025-03-17 00:59:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b37bb890>,
#   'num_nodes': 49,
#   'num_edges': 1152,
#   'num_measurements': 2151},
#  {'timestamp': Timestamp('2025-03-17 00:59:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b37ff590>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2279},
#  {'timestamp': Timestamp('2025-03-17 00:59:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b383f4d0>,
#   'num_nodes': 49,
#   'num_edges': 1154,
#   'num_measurements': 2261},
#  {'timestamp': Timestamp('2025-03-17 01:00:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b3883250>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2246},
#  {'timestamp': Timestamp('2025-03-17 01:00:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b36c7210>,
#   'num_nodes': 49,
#   'num_edges': 1139,
#   'num_measurements': 2137},
#  {'timestamp': Timestamp('2025-03-17 01:00:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b3706c50>,
#   'num_nodes': 49,
#   'num_edges': 1157,
#   'num_measurements': 2291},
#  {'timestamp': Timestamp('2025-03-17 01:01:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b3746ad0>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2231},
#  {'timestamp': Timestamp('2025-03-17 01:01:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b3786a10>,
#   'num_nodes': 49,
#   'num_edges': 1155,
#   'num_measurements': 2190},
#  {'timestamp': Timestamp('2025-03-17 01:01:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b35ce7d0>,
#   'num_nodes': 49,
#   'num_edges': 1156,
#   'num_measurements': 2274},
#  {'timestamp': Timestamp('2025-03-17 01:02:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b360e5d0>,
#   'num_nodes': 49,
#   'num_edges': 1155,
#   'num_measurements': 2202},
#  {'timestamp': Timestamp('2025-03-17 01:02:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b364e3d0>,
#   'num_nodes': 49,
#   'num_edges': 1164,
#   'num_measurements': 2303},
#  {'timestamp': Timestamp('2025-03-17 01:02:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b3692450>,
#   'num_nodes': 49,
#   'num_edges': 1163,
#   'num_measurements': 2163},
#  {'timestamp': Timestamp('2025-03-17 01:03:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b34d2410>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2239},
#  {'timestamp': Timestamp('2025-03-17 01:03:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b3512390>,
#   'num_nodes': 49,
#   'num_edges': 1154,
#   'num_measurements': 2260},
#  {'timestamp': Timestamp('2025-03-17 01:03:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b3556190>,
#   'num_nodes': 49,
#   'num_edges': 1154,
#   'num_measurements': 2207},
#  {'timestamp': Timestamp('2025-03-17 01:04:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b3599f50>,
#   'num_nodes': 49,
#   'num_edges': 1154,
#   'num_measurements': 2255},
#  {'timestamp': Timestamp('2025-03-17 01:04:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b33d9d50>,
#   'num_nodes': 49,
#   'num_edges': 1157,
#   'num_measurements': 2217},
#  {'timestamp': Timestamp('2025-03-17 01:04:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b3419b90>,
#   'num_nodes': 49,
#   'num_edges': 1152,
#   'num_measurements': 2222},
#  {'timestamp': Timestamp('2025-03-17 01:05:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b345d8d0>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2240},
#  {'timestamp': Timestamp('2025-03-17 01:05:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b34a17d0>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2219},
#  {'timestamp': Timestamp('2025-03-17 01:05:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b32e1510>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2272},
#  {'timestamp': Timestamp('2025-03-17 01:06:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b3321490>,
#   'num_nodes': 49,
#   'num_edges': 1152,
#   'num_measurements': 2183},
#  {'timestamp': Timestamp('2025-03-17 01:06:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b3365190>,
#   'num_nodes': 49,
#   'num_edges': 1154,
#   'num_measurements': 2295},
#  {'timestamp': Timestamp('2025-03-17 01:06:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b33a4f90>,
#   'num_nodes': 49,
#   'num_edges': 1164,
#   'num_measurements': 2199},
#  {'timestamp': Timestamp('2025-03-17 01:07:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b31e8f90>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2228},
#  {'timestamp': Timestamp('2025-03-17 01:07:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b322cf50>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2272},
#  {'timestamp': Timestamp('2025-03-17 01:07:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b326ce50>,
#   'num_nodes': 49,
#   'num_edges': 1163,
#   'num_measurements': 2257},
#  {'timestamp': Timestamp('2025-03-17 01:08:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b32ace50>,
#   'num_nodes': 49,
#   'num_edges': 1148,
#   'num_measurements': 2209},
#  {'timestamp': Timestamp('2025-03-17 01:08:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b30eca90>,
#   'num_nodes': 49,
#   'num_edges': 1165,
#   'num_measurements': 2219},
#  {'timestamp': Timestamp('2025-03-17 01:08:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b3130ad0>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2246},
#  {'timestamp': Timestamp('2025-03-17 01:09:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b3174890>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2231},
#  {'timestamp': Timestamp('2025-03-17 01:09:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b31b4750>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2201},
#  {'timestamp': Timestamp('2025-03-17 01:09:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb3f4690>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2254},
#  {'timestamp': Timestamp('2025-03-17 01:10:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb434610>,
#   'num_nodes': 49,
#   'num_edges': 1164,
#   'num_measurements': 2247},
#  {'timestamp': Timestamp('2025-03-17 01:10:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb4746d0>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2240},
#  {'timestamp': Timestamp('2025-03-17 01:10:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb2b8590>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2212},
#  {'timestamp': Timestamp('2025-03-17 01:11:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb2fc490>,
#   'num_nodes': 49,
#   'num_edges': 1149,
#   'num_measurements': 2236},
#  {'timestamp': Timestamp('2025-03-17 01:11:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb33c110>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2249},
#  {'timestamp': Timestamp('2025-03-17 01:11:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93cb37c050>,
#   'num_nodes': 49,
#   'num_edges': 1146,
#   'num_measurements': 2197},
#  {'timestamp': Timestamp('2025-03-17 01:12:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2bbbc10>,
#   'num_nodes': 49,
#   'num_edges': 1163,
#   'num_measurements': 2266},
#  {'timestamp': Timestamp('2025-03-17 01:12:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2bfbbd0>,
#   'num_nodes': 49,
#   'num_edges': 1146,
#   'num_measurements': 2226},
#  {'timestamp': Timestamp('2025-03-17 01:12:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2c3f790>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2232},
#  {'timestamp': Timestamp('2025-03-17 01:13:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2c7f790>,
#   'num_nodes': 49,
#   'num_edges': 1156,
#   'num_measurements': 2187},
#  {'timestamp': Timestamp('2025-03-17 01:13:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2ac3590>,
#   'num_nodes': 49,
#   'num_edges': 1150,
#   'num_measurements': 2254},
#  {'timestamp': Timestamp('2025-03-17 01:13:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2b03290>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2306},
#  {'timestamp': Timestamp('2025-03-17 01:14:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2b4b150>,
#   'num_nodes': 49,
#   'num_edges': 1156,
#   'num_measurements': 2160},
#  {'timestamp': Timestamp('2025-03-17 01:14:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2b8af90>,
#   'num_nodes': 49,
#   'num_edges': 1151,
#   'num_measurements': 2248},
#  {'timestamp': Timestamp('2025-03-17 01:14:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b29cec50>,
#   'num_nodes': 49,
#   'num_edges': 1149,
#   'num_measurements': 2258},
#  {'timestamp': Timestamp('2025-03-17 01:15:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2a12890>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2200},
#  {'timestamp': Timestamp('2025-03-17 01:15:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2a52790>,
#   'num_nodes': 49,
#   'num_edges': 1154,
#   'num_measurements': 2276},
#  {'timestamp': Timestamp('2025-03-17 01:15:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2a96510>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2221},
#  {'timestamp': Timestamp('2025-03-17 01:16:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b28da250>,
#   'num_nodes': 49,
#   'num_edges': 1156,
#   'num_measurements': 2341},
#  {'timestamp': Timestamp('2025-03-17 01:16:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b291e050>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2107},
#  {'timestamp': Timestamp('2025-03-17 01:16:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b295dd90>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2233},
#  {'timestamp': Timestamp('2025-03-17 01:17:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b299dad0>,
#   'num_nodes': 49,
#   'num_edges': 1156,
#   'num_measurements': 2306},
#  {'timestamp': Timestamp('2025-03-17 01:17:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b27e9910>,
#   'num_nodes': 49,
#   'num_edges': 1150,
#   'num_measurements': 2171},
#  {'timestamp': Timestamp('2025-03-17 01:17:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2829590>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2230},
#  {'timestamp': Timestamp('2025-03-17 01:18:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2869490>,
#   'num_nodes': 49,
#   'num_edges': 1148,
#   'num_measurements': 2217},
#  {'timestamp': Timestamp('2025-03-17 01:18:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b28a90d0>,
#   'num_nodes': 49,
#   'num_edges': 1155,
#   'num_measurements': 2254},
#  {'timestamp': Timestamp('2025-03-17 01:18:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b26f0e90>,
#   'num_nodes': 49,
#   'num_edges': 1157,
#   'num_measurements': 2249},
#  {'timestamp': Timestamp('2025-03-17 01:19:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2730cd0>,
#   'num_nodes': 49,
#   'num_edges': 1154,
#   'num_measurements': 2201},
#  {'timestamp': Timestamp('2025-03-17 01:19:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2774a90>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2313},
#  {'timestamp': Timestamp('2025-03-17 01:19:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b25bc910>,
#   'num_nodes': 49,
#   'num_edges': 1152,
#   'num_measurements': 2175},
#  {'timestamp': Timestamp('2025-03-17 01:20:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b25fc610>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2246},
#  {'timestamp': Timestamp('2025-03-17 01:20:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b263c5d0>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2261},
#  {'timestamp': Timestamp('2025-03-17 01:20:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b267c510>,
#   'num_nodes': 49,
#   'num_edges': 1146,
#   'num_measurements': 2182},
#  {'timestamp': Timestamp('2025-03-17 01:21:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b24c4090>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2224},
#  {'timestamp': Timestamp('2025-03-17 01:21:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b24fff90>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2280},
#  {'timestamp': Timestamp('2025-03-17 01:21:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b253fe90>,
#   'num_nodes': 49,
#   'num_edges': 1143,
#   'num_measurements': 2256},
#  {'timestamp': Timestamp('2025-03-17 01:22:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b257f950>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2198},
#  {'timestamp': Timestamp('2025-03-17 01:22:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b23c3810>,
#   'num_nodes': 49,
#   'num_edges': 1154,
#   'num_measurements': 2235},
#  {'timestamp': Timestamp('2025-03-17 01:22:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b240b5d0>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2285},
#  {'timestamp': Timestamp('2025-03-17 01:23:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b244b510>,
#   'num_nodes': 49,
#   'num_edges': 1155,
#   'num_measurements': 2206},
#  {'timestamp': Timestamp('2025-03-17 01:23:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b248b310>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2233},
#  {'timestamp': Timestamp('2025-03-17 01:23:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b22d31d0>,
#   'num_nodes': 49,
#   'num_edges': 1156,
#   'num_measurements': 2274},
#  {'timestamp': Timestamp('2025-03-17 01:24:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2312fd0>,
#   'num_nodes': 49,
#   'num_edges': 1148,
#   'num_measurements': 2192},
#  {'timestamp': Timestamp('2025-03-17 01:24:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2356c10>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2240},
#  {'timestamp': Timestamp('2025-03-17 01:24:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2396b90>,
#   'num_nodes': 49,
#   'num_edges': 1151,
#   'num_measurements': 2196},
#  {'timestamp': Timestamp('2025-03-17 01:25:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b21de850>,
#   'num_nodes': 49,
#   'num_edges': 1165,
#   'num_measurements': 2318},
#  {'timestamp': Timestamp('2025-03-17 01:25:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b221e890>,
#   'num_nodes': 49,
#   'num_edges': 1152,
#   'num_measurements': 2166},
#  {'timestamp': Timestamp('2025-03-17 01:25:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b225e590>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2282},
#  {'timestamp': Timestamp('2025-03-17 01:26:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b22a6450>,
#   'num_nodes': 49,
#   'num_edges': 1152,
#   'num_measurements': 2272},
#  {'timestamp': Timestamp('2025-03-17 01:26:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b20ea190>,
#   'num_nodes': 49,
#   'num_edges': 1145,
#   'num_measurements': 2225},
#  {'timestamp': Timestamp('2025-03-17 01:26:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2129cd0>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2210},
#  {'timestamp': Timestamp('2025-03-17 01:27:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2169b90>,
#   'num_nodes': 49,
#   'num_edges': 1143,
#   'num_measurements': 2134},
#  {'timestamp': Timestamp('2025-03-17 01:27:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b21ad690>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2339},
#  {'timestamp': Timestamp('2025-03-17 01:27:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b1ff1590>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2219},
#  {'timestamp': Timestamp('2025-03-17 01:28:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2035310>,
#   'num_nodes': 49,
#   'num_edges': 1154,
#   'num_measurements': 2218},
#  {'timestamp': Timestamp('2025-03-17 01:28:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b2079090>,
#   'num_nodes': 49,
#   'num_edges': 1152,
#   'num_measurements': 2266},
#  {'timestamp': Timestamp('2025-03-17 01:28:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b1ebcd90>,
#   'num_nodes': 49,
#   'num_edges': 1134,
#   'num_measurements': 2161},
#  {'timestamp': Timestamp('2025-03-17 01:29:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b1efc610>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2277},
#  {'timestamp': Timestamp('2025-03-17 01:29:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93b1f3c590>,
#   'num_nodes': 49,
#   'num_edges': 1153,
#   'num_measurements': 2247},
# ...
#   'num_edges': 1158,
#   'num_measurements': 2245},
#  {'timestamp': Timestamp('2025-03-17 05:04:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939ab0e5d0>,
#   'num_nodes': 49,
#   'num_edges': 1157,
#   'num_measurements': 2224},
#  {'timestamp': Timestamp('2025-03-17 05:04:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939ab4e410>,
#   'num_nodes': 49,
#   'num_edges': 1157,
#   'num_measurements': 2213},
#  {'timestamp': Timestamp('2025-03-17 05:04:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939ab8e250>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2236},
#  {'timestamp': Timestamp('2025-03-17 05:05:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939abd20d0>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2248},
#  {'timestamp': Timestamp('2025-03-17 05:05:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939aa15f50>,
#   'num_nodes': 49,
#   'num_edges': 1154,
#   'num_measurements': 2194},
#  {'timestamp': Timestamp('2025-03-17 05:05:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939aa59cd0>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2231},
#  {'timestamp': Timestamp('2025-03-17 05:06:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939aa99b90>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2243},
#  {'timestamp': Timestamp('2025-03-17 05:06:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939aadda10>,
#   'num_nodes': 49,
#   'num_edges': 1157,
#   'num_measurements': 2224},
#  {'timestamp': Timestamp('2025-03-17 05:06:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a921850>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2216},
#  {'timestamp': Timestamp('2025-03-17 05:07:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a961750>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2237},
#  {'timestamp': Timestamp('2025-03-17 05:07:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a9a95d0>,
#   'num_nodes': 49,
#   'num_edges': 1157,
#   'num_measurements': 2230},
#  {'timestamp': Timestamp('2025-03-17 05:07:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a9e9450>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2222},
#  {'timestamp': Timestamp('2025-03-17 05:08:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a82d350>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2230},
#  {'timestamp': Timestamp('2025-03-17 05:08:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a86d1d0>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2249},
#  {'timestamp': Timestamp('2025-03-17 05:08:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a8b10d0>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2206},
#  {'timestamp': Timestamp('2025-03-17 05:09:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a8f4f50>,
#   'num_nodes': 49,
#   'num_edges': 1163,
#   'num_measurements': 2232},
#  {'timestamp': Timestamp('2025-03-17 05:09:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a738f10>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2239},
#  {'timestamp': Timestamp('2025-03-17 05:09:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a77cd90>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2225},
#  {'timestamp': Timestamp('2025-03-17 05:10:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a7bcc90>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2221},
#  {'timestamp': Timestamp('2025-03-17 05:10:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a600b10>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2237},
#  {'timestamp': Timestamp('2025-03-17 05:10:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a644a50>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2251},
#  {'timestamp': Timestamp('2025-03-17 05:11:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a688950>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2195},
#  {'timestamp': Timestamp('2025-03-17 05:11:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a6c87d0>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2230},
#  {'timestamp': Timestamp('2025-03-17 05:11:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a50c710>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2235},
#  {'timestamp': Timestamp('2025-03-17 05:12:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a550690>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2231},
#  {'timestamp': Timestamp('2025-03-17 05:12:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a590650>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2219},
#  {'timestamp': Timestamp('2025-03-17 05:12:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a5d4590>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2235},
#  {'timestamp': Timestamp('2025-03-17 05:13:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a4184d0>,
#   'num_nodes': 49,
#   'num_edges': 1164,
#   'num_measurements': 2253},
#  {'timestamp': Timestamp('2025-03-17 05:13:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a45c4d0>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2202},
#  {'timestamp': Timestamp('2025-03-17 05:13:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a49c390>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2231},
#  {'timestamp': Timestamp('2025-03-17 05:14:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a4dc2d0>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2241},
#  {'timestamp': Timestamp('2025-03-17 05:14:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a328210>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2231},
#  {'timestamp': Timestamp('2025-03-17 05:14:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a368110>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2221},
#  {'timestamp': Timestamp('2025-03-17 05:15:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a3a8050>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2229},
#  {'timestamp': Timestamp('2025-03-17 05:15:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a3dff90>,
#   'num_nodes': 49,
#   'num_edges': 1158,
#   'num_measurements': 2234},
#  {'timestamp': Timestamp('2025-03-17 05:15:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a227e10>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2222},
#  {'timestamp': Timestamp('2025-03-17 05:16:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a267dd0>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2231},
#  {'timestamp': Timestamp('2025-03-17 05:16:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a2abcd0>,
#   'num_nodes': 49,
#   'num_edges': 1159,
#   'num_measurements': 2245},
#  {'timestamp': Timestamp('2025-03-17 05:16:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a2ebb90>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2230},
#  {'timestamp': Timestamp('2025-03-17 05:17:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a12fb10>,
#   'num_nodes': 49,
#   'num_edges': 1157,
#   'num_measurements': 2215},
#  {'timestamp': Timestamp('2025-03-17 05:17:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a177950>,
#   'num_nodes': 49,
#   'num_edges': 1163,
#   'num_measurements': 2241},
#  {'timestamp': Timestamp('2025-03-17 05:17:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a1b7910>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2232},
#  {'timestamp': Timestamp('2025-03-17 05:18:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a1f7890>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2225},
#  {'timestamp': Timestamp('2025-03-17 05:18:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a03b810>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2233},
#  {'timestamp': Timestamp('2025-03-17 05:18:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a07f790>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2247},
#  {'timestamp': Timestamp('2025-03-17 05:19:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939a0c36d0>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2211},
#  {'timestamp': Timestamp('2025-03-17 05:19:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399f07610>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2231},
#  {'timestamp': Timestamp('2025-03-17 05:19:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399f4b590>,
#   'num_nodes': 49,
#   'num_edges': 1165,
#   'num_measurements': 2245},
#  {'timestamp': Timestamp('2025-03-17 05:20:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399f8b610>,
#   'num_nodes': 49,
#   'num_edges': 1165,
#   'num_measurements': 2234},
#  {'timestamp': Timestamp('2025-03-17 05:20:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399fcb650>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2222},
#  {'timestamp': Timestamp('2025-03-17 05:20:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399e0f5d0>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2234},
#  {'timestamp': Timestamp('2025-03-17 05:21:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399e57510>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2258},
#  {'timestamp': Timestamp('2025-03-17 05:21:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399e97450>,
#   'num_nodes': 49,
#   'num_edges': 1160,
#   'num_measurements': 2204},
#  {'timestamp': Timestamp('2025-03-17 05:21:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399ed7350>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2231},
#  {'timestamp': Timestamp('2025-03-17 05:22:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399d1f2d0>,
#   'num_nodes': 49,
#   'num_edges': 1164,
#   'num_measurements': 2243},
#  {'timestamp': Timestamp('2025-03-17 05:22:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399d5f2d0>,
#   'num_nodes': 49,
#   'num_edges': 1164,
#   'num_measurements': 2233},
#  {'timestamp': Timestamp('2025-03-17 05:22:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399da32d0>,
#   'num_nodes': 49,
#   'num_edges': 1163,
#   'num_measurements': 2221},
#  {'timestamp': Timestamp('2025-03-17 05:23:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399de32d0>,
#   'num_nodes': 49,
#   'num_edges': 1163,
#   'num_measurements': 2237},
#  {'timestamp': Timestamp('2025-03-17 05:23:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399c2b2d0>,
#   'num_nodes': 49,
#   'num_edges': 1166,
#   'num_measurements': 2240},
#  {'timestamp': Timestamp('2025-03-17 05:23:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399c6b350>,
#   'num_nodes': 49,
#   'num_edges': 1165,
#   'num_measurements': 2226},
#  {'timestamp': Timestamp('2025-03-17 05:24:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399cab390>,
#   'num_nodes': 49,
#   'num_edges': 1164,
#   'num_measurements': 2232},
#  {'timestamp': Timestamp('2025-03-17 05:24:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399cf3390>,
#   'num_nodes': 49,
#   'num_edges': 1165,
#   'num_measurements': 2243},
#  {'timestamp': Timestamp('2025-03-17 05:24:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399b373d0>,
#   'num_nodes': 49,
#   'num_edges': 1164,
#   'num_measurements': 2232},
#  {'timestamp': Timestamp('2025-03-17 05:25:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399b773d0>,
#   'num_nodes': 49,
#   'num_edges': 1163,
#   'num_measurements': 2223},
#  {'timestamp': Timestamp('2025-03-17 05:25:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399bb7390>,
#   'num_nodes': 49,
#   'num_edges': 1164,
#   'num_measurements': 2227},
#  {'timestamp': Timestamp('2025-03-17 05:25:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399bfb390>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2232},
#  {'timestamp': Timestamp('2025-03-17 05:26:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399a43310>,
#   'num_nodes': 49,
#   'num_edges': 1165,
#   'num_measurements': 2222},
#  {'timestamp': Timestamp('2025-03-17 05:26:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399a83350>,
#   'num_nodes': 49,
#   'num_edges': 1167,
#   'num_measurements': 2236},
#  {'timestamp': Timestamp('2025-03-17 05:26:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399ac7410>,
#   'num_nodes': 49,
#   'num_edges': 1166,
#   'num_measurements': 2245},
#  {'timestamp': Timestamp('2025-03-17 05:27:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939990b490>,
#   'num_nodes': 49,
#   'num_edges': 1166,
#   'num_measurements': 2223},
#  {'timestamp': Timestamp('2025-03-17 05:27:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939994b550>,
#   'num_nodes': 49,
#   'num_edges': 1164,
#   'num_measurements': 2231},
#  {'timestamp': Timestamp('2025-03-17 05:27:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939998f550>,
#   'num_nodes': 49,
#   'num_edges': 1166,
#   'num_measurements': 2244},
#  {'timestamp': Timestamp('2025-03-17 05:28:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93999d3650>,
#   'num_nodes': 49,
#   'num_edges': 1167,
#   'num_measurements': 2231},
#  {'timestamp': Timestamp('2025-03-17 05:28:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399817710>,
#   'num_nodes': 49,
#   'num_edges': 1166,
#   'num_measurements': 2226},
#  {'timestamp': Timestamp('2025-03-17 05:28:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399857790>,
#   'num_nodes': 49,
#   'num_edges': 1167,
#   'num_measurements': 2234},
#  {'timestamp': Timestamp('2025-03-17 05:29:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939989b890>,
#   'num_nodes': 49,
#   'num_edges': 1164,
#   'num_measurements': 2251},
#  {'timestamp': Timestamp('2025-03-17 05:29:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93998df890>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2210},
#  {'timestamp': Timestamp('2025-03-17 05:29:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399723810>,
#   'num_nodes': 49,
#   'num_edges': 1166,
#   'num_measurements': 2233},
#  {'timestamp': Timestamp('2025-03-17 05:30:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399763890>,
#   'num_nodes': 49,
#   'num_edges': 1166,
#   'num_measurements': 2238},
#  {'timestamp': Timestamp('2025-03-17 05:30:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93997a7910>,
#   'num_nodes': 49,
#   'num_edges': 1165,
#   'num_measurements': 2235},
#  {'timestamp': Timestamp('2025-03-17 05:30:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93997e7950>,
#   'num_nodes': 49,
#   'num_edges': 1165,
#   'num_measurements': 2224},
#  {'timestamp': Timestamp('2025-03-17 05:31:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939962f990>,
#   'num_nodes': 49,
#   'num_edges': 1164,
#   'num_measurements': 2227},
#  {'timestamp': Timestamp('2025-03-17 05:31:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399673990>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2236},
#  {'timestamp': Timestamp('2025-03-17 05:31:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93996b3910>,
#   'num_nodes': 49,
#   'num_edges': 1163,
#   'num_measurements': 2220},
#  {'timestamp': Timestamp('2025-03-17 05:32:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93996f38d0>,
#   'num_nodes': 49,
#   'num_edges': 1161,
#   'num_measurements': 2226},
#  {'timestamp': Timestamp('2025-03-17 05:32:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f9399537810>,
#   'num_nodes': 49,
#   'num_edges': 1165,
#   'num_measurements': 2243},
#  {'timestamp': Timestamp('2025-03-17 05:32:40'),
#   'graph': <networkx.classes.graph.Graph at 0x7f939957f850>,
#   'num_nodes': 49,
#   'num_edges': 1164,
#   'num_measurements': 2235},
#  {'timestamp': Timestamp('2025-03-17 05:33:00'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93995bf850>,
#   'num_nodes': 49,
#   'num_edges': 1162,
#   'num_measurements': 2221},
#  {'timestamp': Timestamp('2025-03-17 05:33:20'),
#   'graph': <networkx.classes.graph.Graph at 0x7f93994037d0>,
#   'num_nodes': 49,
#   'num_edges': 1163,
#   'num_measurements': 2232},
#  ...]

# %%
nx.draw(temporal_graphs[0]['graph'])
plt.show()

# %%
path = "./RSSI/3cfe_RSSI_elevage_3_cut.parquet"
rssi = pd.read_parquet(path, engine="pyarrow")

# %%
rssi
# Out:
#         RSSI  tick_accel_day   tick_accel  ble_id accelero_id  \
# 0        -44         11.9375  305627.1875     242        3cf2
# 1        -30         11.9375  305627.1875     101        3665
# 2        -43         11.9375  305627.1875      93        365d
# 3        -35         12.0625  305627.3125     109        366d
# 4        -45         12.0625  305627.3125       9        3d09
# ...      ...             ...          ...     ...         ...
# 290108   -80      86332.7500  910347.3750     241        3cf1
# 290109   -81      86334.9375  910349.5625     108        366c
# 290110   -79      86348.7500  910363.3750     253        3cfd
# 290111   -78      86348.8750  910363.5000      12        3d0c
# 290112   -67      86349.6875  910364.3125     247        3cf7
#
#                 relative_DateTime
# 0      2025-03-17 00:01:01.937500
# 1      2025-03-17 00:01:01.937500
# 2      2025-03-17 00:01:01.937500
# 3      2025-03-17 00:01:02.062500
# 4      2025-03-17 00:01:02.062500
# ...                           ...
# 290108 2025-03-23 23:59:41.750000
# 290109 2025-03-23 23:59:43.937500
# 290110 2025-03-23 23:59:57.750000
# 290111 2025-03-23 23:59:57.875000
# 290112 2025-03-23 23:59:58.687500
#
# [290113 rows x 6 columns]

# %%
path = "Accelerometer/366d_accel_elevage_3_cut.parquet"
acc = pd.read_parquet(path, engine="pyarrow")
acc
# Out:
#             acc_x     acc_y     acc_z  tick_accel_day   tick_accel  \
# 0        0.990234  0.150391 -0.239258      86342.0625  305647.2500
# 1        0.991211  0.145508 -0.242188      86342.1250  305647.3125
# 2        0.992188  0.149414 -0.240234      86342.1875  305647.3750
# 3        0.991211  0.150391 -0.239258      86342.2500  305647.4375
# 4        0.990234  0.150391 -0.241211      86342.3125  305647.5000
# ...           ...       ...       ...             ...          ...
# 9676784 -0.657224  0.247967 -0.649461     172749.6875  910446.2500
# 9676785 -0.657224  0.247967 -0.649461     172749.7500  910446.3125
# 9676786 -0.657224  0.247967 -0.649461     172749.8125  910446.3750
# 9676787 -0.657224  0.247967 -0.649461     172749.8750  910446.4375
# 9676788 -0.657224  0.247967 -0.649461     172749.9375  910446.5000
#
#                  relative_DateTime  generated_data
# 0       2025-03-17 00:00:00.062500           False
# 1       2025-03-17 00:00:00.125000           False
# 2       2025-03-17 00:00:00.187500           False
# 3       2025-03-17 00:00:00.250000           False
# 4       2025-03-17 00:00:00.312500           False
# ...                            ...             ...
# 9676784 2025-03-23 23:59:58.687500            True
# 9676785 2025-03-23 23:59:58.750000            True
# 9676786 2025-03-23 23:59:58.812500            True
# 9676787 2025-03-23 23:59:58.875000            True
# 9676788 2025-03-23 23:59:58.937500            True
#
# [9676789 rows x 7 columns]
